# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver = webdriver.Chrome(r"C:\Users\502770913\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.cardekho.com/')

# %%
search_button=driver.find_element_by_xpath("/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span")
search_button.click()

# %%
url="https://www.cardekho.com/used-cars+in+new-delhi"

# %%
driver.get(url)

# %%
model=[]
variant=[]
price=[]
KMs_Driven=[]
fuel=[]
manufacturing_year=[]
Reg_year=[]
Engine_Displacement=[]
No_Of_Owner=[]
RTO=[]
Transmission=[]
Insurance_Type=[]

# %%
model=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[2]/div[1]/div/div/div/div[1]/div[1]/h1")
model[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="85ebf7f2-d845-471e-9eb7-cdb65dca9114")>]

# %%
for i in model:
    title=i.text
    print(title)
# Out:
# 2016 Renault KWID

# %%
variant=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[2]/div[1]/div/div/div/div[1]/div[1]/div[1]")
variant[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="6484fff3-75b9-494b-80c3-f096295d66ed")>]

# %%
for i in variant:
    title=i.text
    print(title)
# Out:
# RXT

# %%
price=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]/span[2]")
price[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="0a6deaed-238c-4b6e-b6e1-3bea7b87ab1b")>]

# %%
for i in price:
    title=i.text
    print(title)
# Out:
# 2,45,000

# %%
KMs_Driven=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[4]/div/div[2]")
KMs_Driven[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="f97cb191-417c-4202-b518-502ec68fd46d")>]

# %%
for i in KMs_Driven:
    title=i.text
    print(title)
# Out:
# 36,575 Kms

# %%
fuel=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[3]/div/div[2]")
fuel[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="42caf68c-1778-480a-8340-8ee1b3d0f26d")>]

# %%
for i in fuel:
    title=i.text
    print(title)
# Out:
# Petrol

# %%
manufacturing_year=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[1]/div/div[2]")
manufacturing_year[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="7ebc7832-4dbd-4306-acb2-814dd7964ecb")>]

# %%
for i in manufacturing_year:
    title=i.text
    print(title)
# Out:
# 2016

# %%
Reg_year=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[2]/div/div[2]")
Reg_year[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="066e6511-eb8e-4682-9fda-fc7bd088b59d")>]

# %%
for i in Reg_year:
    title=i.text
    print(title)
# Out:
# May 2016

# %%
Engine_Displacement=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[5]/div/div[2]")
Engine_Displacement[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="b1a164b7-121a-4d12-8bdc-1716344fb89c")>]

# %%
for i in Engine_Displacement:
    title=i.text
    print(title)
# Out:
# 799 cc

# %%
No_Of_Owner=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[6]/div/div[2]")
No_Of_Owner[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="6d314f78-2eab-4f08-9df4-6360de395707")>]

# %%
for i in No_Of_Owner:
    title=i.text
    print(title)
# Out:
# 1st Owner

# %%
RTO=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[7]/div/div[2]")
RTO[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="c5d14b15-1125-47f0-b382-c590522c516b")>]

# %%
for i in RTO:
    title=i.text
    print(title)
# Out:
# DL8C

# %%
Transmission=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[8]/div/div[2]")
Transmission[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="7d7c50d6-3d18-44d9-8eeb-08d3e6ce8682")>]

# %%
for i in Transmission:
    title=i.text
    print(title)
# Out:
# Manual

# %%
Insurance_Type=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[9]/div/div[2]")
Insurance_Type[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3a4a507cdc6e2466bc47b729fdd3dfb9", element="d3cee6a6-fd4d-49db-8fa1-6e80b13a31b4")>]

# %%
for i in Insurance_Type:
    title=i.text
    print(title)
# Out:
# Third Party insurance

# %%
for i in range(1, 500):
    model=driver.find_elements_by_xpath(f"/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[1]/div[6]/div[{i}]")
    car_details = []
    for j in model:
        car_details = j.text.split("\n")
    if ("Petrol" in car_details or "Diesel" in car_details) and ("Manual" in car_details or "Automatic" in car_details):
        print("========================================================")
        print("Sr No: ", i)
        print(car_details)
        print("========================================================")
# Out:
# ...
# Sr No:  1
# ['2016 Renault KWID', 'RXT', '₹2.45 Lakh', '36,575 kms', 'Petrol', 'Manual', 'Trustmark']
# ...
# Sr No:  2
# ['2018 Tata Nexon', '1.5 Revotorq XZA Plus', '₹8.19 Lakh₹ 8,26,000Save ₹7,000', '69,828 kms', 'Diesel', 'Automatic', 'Trustmark']
# ...
# Sr No:  3
# ['2019 Maruti S-Presso', 'VXI AT', '₹4.20 Lakh₹ 4,40,000Save ₹20,000', '30,549 kms', 'Petrol', 'Automatic', 'Trustmark']
# ...
# Sr No:  5
# ['2018 Hyundai Grand i10', '1.2 Kappa Sportz BSIV', '₹5.20 Lakh₹ 5,50,000Save ₹30,000', '15,533 kms', 'Petrol', 'Manual', 'Trustmark']
# ...
# Sr No:  6
# ['2016 Honda Jazz', '1.2 SV i VTEC', '₹4.34 Lakh₹ 5,10,000Save ₹76,000', '29,147 kms', 'Petrol', 'Manual', 'Trustmark']
# ...
# Sr No:  7
# ['2015 Hyundai Verna', '1.6 CRDi SX', '₹5.52 Lakh₹ 5,57,000Save ₹5,000', '99,701 kms', 'Diesel', 'Manual', 'Trustmark']
# ...
# Sr No:  8
# ['2019 Maruti Ciaz', 'Sigma BSIV', '₹7.79 Lakh', '36,653 kms', 'Petrol', 'Manual', 'Trustmark']
# ...
# Sr No:  9
# ...
